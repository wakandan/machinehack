# %%
# %load_ext lab_black

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
import numpy as np
import re
import math
import tensorflow as tf
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.corpus import stopwords
from textblob import Word
from gensim.models import Word2Vec
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from livelossplot import PlotLossesKeras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_validate, KFold
from sklearn.metrics import make_scorer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import FunctionTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_extraction.text import (
    CountVectorizer,
    TfidfVectorizer,
    HashingVectorizer,
)
from lightgbm import LGBMRegressor
import scipy
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
train = pd.read_excel("Data_Train.xlsx")
test = pd.read_excel("Test_set.xlsx")
print("train shape before", train.shape)
train.drop(train[train.Price > 22270.0].index, inplace=True)
print("train shape after", train.shape)
train["istrain"] = 1
test["istrain"] = 0
traintest = pd.concat([train, test], axis=0)
# Out:
# train shape before (10683, 11)
# train shape after (10583, 11)

# %%
train.Price.quantile(0.999)
# Out:
# 22270.0

# %%
plt.plot(train.Price, ".")

# %%
traintest["is_premium_economy"] = traintest.Airline.str.contains("Premium").astype(int)

# %%
traintest["is_business"] = traintest.Airline.str.contains("Business").astype(int)
traintest.loc[traintest.Additional_Info.str.contains("Business"), "is_business"] = 1

# %%
traintest["Date_of_Journey"] = pd.to_datetime(
    traintest.Date_of_Journey, format="%d/%m/%Y"
)

# %%
def countboth(col):
    fig, axes = plt.subplots(1, 3, figsize=(20, 10), sharey=True)
    axes[0].set_title("train")
    sns.countplot(data=traintest[traintest.istrain == 1], y=col, ax=axes[0])
    axes[1].set_title("test")
    sns.countplot(data=traintest[traintest.istrain == 0], y=col, ax=axes[1])
    axes[2].set_title("all")
    sns.countplot(data=traintest, y=col, ax=axes[2])


traintest["month"] = traintest.Date_of_Journey.dt.month

# %%
traintest["day"] = traintest.Date_of_Journey.dt.day

# %% [markdown]
# the distribution for day, month are very similar. Seems like the data are properly shuffled and divided

# %%
traintest["weekday"] = traintest.Date_of_Journey.dt.weekday

# %% [markdown]
# distribution for weekday is also very similar

# %% [markdown]
# seems like the most common source is Delhi and the most common destination is Cochin. Perhaps we can draw the distribution of source to destination

# %%
traintest[
    ["Source", "Destination"]
].drop_duplicates()  # there are only 6 routes for the entire dataset!
# Out:
#       Source Destination
# 0   Banglore   New Delhi
# 1    Kolkata    Banglore
# 2      Delhi      Cochin
# 12   Chennai     Kolkata
# 22  Banglore       Delhi
# 59    Mumbai   Hyderabad

# %%
traintest["Total_Stops"] = traintest.Total_Stops.str.extract("(\d+)").fillna(0)

# %%
traintest["Total_Stops"] = traintest["Total_Stops"].astype(int)

# %%
traintest.Additional_Info.value_counts()
# Out:
# No info                         10410
# In-flight meal not included      2426
# No check-in baggage included      396
# 1 Long layover                     10
# Change airports                     7
# No Info                             3
# Business class                      1
# Red-eye flight                      1
# Name: Additional_Info, dtype: int64

# %%
traintest.loc[traintest.Additional_Info == "No Info", "Additional_Info"] = "No info"

# %%
traintest.loc[traintest.Additional_Info == "Business class", "is_business"] = 1

# %%
traintest.loc[
    traintest.Destination == "New Delhi", "Destination"
] = "Delhi"  # delhi and new delhi are the same, rename the destination for consistency

# %%
traintest["duration_mins"] = (
    traintest.Duration.str.extract(".* (\d+)m").fillna(0).astype(int)
)

# %%
traintest["duration_hours"] = (
    traintest.Duration.str.extract("(\d+)h.*").fillna(0).astype(int)
)

# %%
traintest["total_duration"] = traintest.duration_hours * 60 + traintest.duration_mins

# %%
traintest.total_duration.hist(bins=40)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=traintest, x="total_duration", y="Price")
# Out:
# <AxesSubplot:xlabel='total_duration', ylabel='Price'>

# %%
plt.plot(traintest.total_duration, ".")

# %%
traintest.total_duration.quantile(0.995)
# Out:
# 2240.0

# %%
traintest[traintest.total_duration > 2240]
# Out:
#            Airline Date_of_Journey    Source Destination  \
#
# 553          DEL → AMD → BOM → COK    05:00  19:15 10 Mar  38h 15m
# 1067         DEL → IDR → BOM → COK    05:25  04:25 05 Mar      47h
# 1113         DEL → IDR → BOM → COK    05:25  19:45 07 Mar  38h 20m
# 1551         DEL → IXC → BOM → COK    06:20  19:45 28 Mar  37h 25m
# 1657         DEL → AMD → BOM → COK    05:00  19:15 13 Jun  38h 15m
# 1804         DEL → AMD → BOM → COK    05:00  19:15 07 Mar  38h 15m
# 2172   DEL → RPR → NAG → BOM → COK    05:15  19:15 19 May      38h
# 2553         CCU → GAU → DEL → BLR    09:50  23:15 25 Mar  37h 25m
# 2654         DEL → JAI → BOM → COK    05:30  19:45 07 Mar  38h 15m
# 2718   DEL → RPR → NAG → BOM → COK    05:15  19:15 10 Mar      38h
# 3790         DEL → IDR → BOM → COK    05:25  19:45 07 Mar  38h 20m
# 3815   DEL → RPR → NAG → BOM → COK    05:15  19:15 22 Mar      38h
# 3966         DEL → AMD → BOM → COK    05:00  19:15 07 Jun  38h 15m
# 4047         DEL → AMD → BOM → COK    05:00  19:15 16 May  38h 15m
# 4118   DEL → RPR → NAG → BOM → COK    05:15  19:15 16 Jun      38h
# 4463   DEL → RPR → NAG → BOM → COK    05:15  19:15 02 Jun      38h
# 4655   DEL → RPR → NAG → BOM → COK    05:15  19:15 28 Jun      38h
# 5711         BOM → BHO → DEL → HYD    06:00  19:25 07 Mar  37h 25m
# 5933         DEL → AMD → BOM → COK    05:00  19:15 10 May  38h 15m
# 5953         DEL → IDR → BOM → COK    10:20  04:25 23 Mar   42h 5m
# 6059         DEL → MAA → BOM → COK    05:10  19:45 28 Mar  38h 35m
# 6321         BLR → BOM → AMD → DEL    08:50  23:55 02 Mar   39h 5m
# 6476         DEL → MAA → BOM → COK    05:10  19:45 28 Mar  38h 35m
# 6884   DEL → RPR → NAG → BOM → COK    05:15  19:15 28 Jun      38h
# 7189         BOM → BHO → DEL → HYD    06:00  19:25 13 Mar  37h 25m
# 7306         DEL → AMD → BOM → COK    05:00  19:15 04 Mar  38h 15m
# 7329         DEL → IDR → BOM → COK    05:25  19:45 28 Mar  38h 20m
# 7553         DEL → IXC → BOM → COK    06:20  19:45 28 Mar  37h 25m
# 7612         BLR → BOM → BHO → DEL    08:50  23:25 16 Mar  38h 35m
# 7876   DEL → RPR → NAG → BOM → COK    05:15  19:15 07 Jun      38h
# 7906         CCU → GAU → DEL → BLR    05:55  23:15 25 Mar  41h 20m
# 8127         DEL → AMD → BOM → COK    05:00  19:15 10 Jun  38h 15m
# 8153   DEL → RPR → NAG → BOM → COK    05:15  19:15 10 May      38h
# 8360         DEL → IDR → BOM → COK    05:25  19:45 07 Mar  38h 20m
# 8409         DEL → JAI → BOM → COK    09:40  04:25 23 Mar  42h 45m
# 8412         DEL → IDR → BOM → COK    05:25  19:45 28 Mar  38h 20m
# 8601   DEL → RPR → NAG → BOM → COK    05:15  19:15 28 May      38h
# 8729   DEL → RPR → NAG → BOM → COK    05:15  19:15 25 Jun      38h
# 9247         DEL → IDR → BOM → COK    05:25  18:50 04 Mar  37h 25m
# 9396         DEL → IDR → BOM → COK    05:25  18:50 22 Mar  37h 25m
# 9484   DEL → RPR → NAG → BOM → COK    05:15  19:15 22 Mar      38h
# 9551         DEL → AMD → BOM → COK    05:00  19:15 28 Mar  38h 15m
# 9673         DEL → AMD → BOM → COK    05:00  19:15 22 May  38h 15m
# 9848         BLR → BOM → AMD → DEL    08:50  23:55 02 Mar   39h 5m
# 10020        DEL → AMD → BOM → COK    05:00  19:15 10 May  38h 15m
# 10326        BLR → CCU → GAU → DEL    05:50  22:10 07 Mar  40h 20m
# 10456        DEL → AMD → BOM → COK    19:10  18:50 08 Mar  47h 40m
# 10639  DEL → RPR → NAG → BOM → COK    05:15  19:15 04 Jun      38h
# 251    DEL → RPR → NAG → BOM → COK    05:15  19:15 28 May      38h
# 510          DEL → AMD → BOM → COK    05:00  19:15 22 Mar  38h 15m
# 1279         BLR → BOM → AMD → DEL    08:50  23:55 13 Mar   39h 5m
# 1379         DEL → AMD → BOM → COK    05:00  19:15 16 Jun  38h 15m
# 1689   DEL → RPR → NAG → BOM → COK    05:15  19:15 07 May      38h
# 1945         DEL → JAI → BOM → COK    05:30  19:45 07 Mar  38h 15m
# 2359         BLR → BOM → BHO → DEL    06:45  23:25 02 Mar  40h 40m
# 2472         DEL → MAA → BOM → COK    05:10  19:45 28 Mar  38h 35m
# 2492         DEL → IDR → BOM → COK    05:25  19:45 07 Mar  38h 20m
#
#        Total_Stops              Additional_Info    Price  istrain  \
# 226              2                      No info  18799.0        1
# 553              2                      No info  10598.0        1
# 1067             2                      No info  20064.0        1
# 1113             2  In-flight meal not included  16389.0        1
# 1551             2  In-flight meal not included   9296.0        1
# 1657             2                      No info   9443.0        1
# 1804             2                      No info  10283.0        1
# 2172             3                      No info  10703.0        1
# 2553             2                      No info  14410.0        1
# 2654             2  In-flight meal not included  15864.0        1
# 2718             3                      No info  15586.0        1
# 3790             2                      No info  16914.0        1
# 3815             3                      No info   9128.0        1
# 3966             2                      No info   9653.0        1
# 4047             2                      No info  10493.0        1
# 4118             3                      No info  10703.0        1
# 4463             3                      No info  10703.0        1
# 4655             3                      No info  10703.0        1
# 5711             2                      No info  13904.0        1
# 5933             2                      No info  10441.0        1
# 5953             2                      No info  11664.0        1
# 6059             2  In-flight meal not included   8098.0        1
# 6321             2                      No info  17135.0        1
# 6476             2  In-flight meal not included   8938.0        1
# 6884             3                      No info  10703.0        1
# 7189             2                      No info  12119.0        1
# 7306             2                      No info  10283.0        1
# 7329             2                      No info  11664.0        1
# 7553             2                      No info  12273.0        1
# 7612             2                      No info  10783.0        1
# 7876             3                      No info  10703.0        1
# 7906             2                      No info  13990.0        1
# 8127             2                      No info   9968.0        1
# 8153             3                      No info  10703.0        1
# 8360             2                      No info  16914.0        1
# 8409             2                      No info  12819.0        1
# 8412             2  In-flight meal not included   9254.0        1
# 8601             3                      No info  10493.0        1
# 8729             3                      No info  10493.0        1
# 9247             2                      No info  20064.0        1
# 9396             2                      No info  12814.0        1
# 9484             3                      No info   9128.0        1
# 9551             2                      No info   8026.0        1
# 9673             2                      No info   9968.0        1
# 9848             2                      No info  17135.0        1
# 10020            2                      No info   9653.0        1
# 10326            2                      No info  11791.0        1
# 10456            2                      No info  20694.0        1
# 10639            3                      No info  10493.0        1
# 251              3                      No info      NaN        0
# 510              2                      No info      NaN        0
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Price'>

# %%
traintest["air"] = traintest.Airline
traintest["air"] = traintest.air.str.replace(" Premium economy", "")
traintest["air"] = traintest.air.str.replace(" Business", "")

# %%
traintest.air.value_counts()
# Out:
# Jet Airways          4683
# IndiGo               2564
# Air India            2175
# Multiple carriers    1549
# SpiceJet             1025
# Vistara               613
# Air Asia              405
# GoAir                 239
# Trujet                  1
# Name: air, dtype: int64

# %%
plt.plot(traintest.Price, ".")

# %%
traintest.Price.quantile(0.999)
# Out:
# 22270.0

# %%
traintest.Additional_Info.value_counts()
# Out:
# No info                         10413
# In-flight meal not included      2426
# No check-in baggage included      396
# 1 Long layover                     10
# Change airports                     7
# Business class                      1
# Red-eye flight                      1
# Name: Additional_Info, dtype: int64

# %%
traintest["meal_not_included"] = traintest.Additional_Info.str.contains(
    "meal not included"
).astype(int)
traintest["baggage_not_included"] = traintest.Additional_Info.str.contains(
    "baggage included"
).astype(int)

# %%
sns.boxplot(data=traintest, x="Source", y="Price")
# Out:
# <AxesSubplot:xlabel='Source', ylabel='Price'>

# %%
sns.boxplot(data=traintest, x="Destination", y="Price")
# Out:
# <AxesSubplot:xlabel='Destination', ylabel='Price'>

# %%
sns.scatterplot(data=traintest, x="total_duration", y="Price")
# Out:
# <AxesSubplot:xlabel='total_duration', ylabel='Price'>

# %%
traintest["departer_hour"] = traintest.Dep_Time.apply(lambda x: int(x.split(":")[0]))

# %%
sns.scatterplot(data=traintest, x="departer_hour", y="Price")
# Out:
# <AxesSubplot:xlabel='departer_hour', ylabel='Price'>

# %%
plt.plot(traintest["total_duration"], ".")

# %%
traintest.Price.apply(lambda x: math.log(x)).hist(bins=60)
# Out:
# <AxesSubplot:>

# %%
traintest["arrival_hour"] = traintest.Arrival_Time.str.extract("(\d+):").astype(int)

# %%
traintest["is_arrival_early_morning"] = (traintest.arrival_hour < 7).astype(int)
traintest["is_arrival_late_evening"] = (traintest.arrival_hour >= 18).astype(int)
traintest.loc[
    (traintest.arrival_hour >= 7) & (traintest.arrival_hour < 18), "is_arrival_daytime"
] = 1
traintest["is_arrival_daytime"] = traintest["is_arrival_daytime"].fillna(0)
traintest["is_arrival_daytime"] = traintest["is_arrival_daytime"].astype(int)

# %%
traintest.is_arrival_daytime.value_counts()
# Out:
# 0    7898
# 1    5356
# Name: is_arrival_daytime, dtype: int64

# %%
traintest["Route"] = traintest.Route.str.replace("[^\w ]", "")
# Out:
# /Users/kdang/anaconda3/envs/kaggle/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
traintest.loc[traintest.Route.isnull(), "Route"] = "DEL COK"  # fix data error

# %%
traintest["transit1"] = traintest.Route.apply(
    lambda x: x.split()[1] if len(x.split()) > 2 else np.nan
).fillna("INVALID")
traintest["transit2"] = traintest.Route.apply(
    lambda x: x.split()[2] if len(x.split()) > 3 else np.nan
).fillna("INVALID")
traintest["transit3"] = traintest.Route.apply(
    lambda x: x.split()[3] if len(x.split()) > 4 else np.nan
).fillna("INVALID")

# %%
traintest[traintest.Route.isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Route, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional_Info, Price, istrain, is_premium_economy, is_business, month, day, weekday, duration_mins, duration_hours, total_duration, air, meal_not_included, baggage_not_included, departer_hour, arrival_hour, is_arrival_early_morning, is_arrival_late_evening, is_arrival_daytime, transit1, transit2, transit3]
# Index: []
#
# [0 rows x 31 columns]

# %%
traintest["is_early_morning"] = (traintest.departer_hour < 7).astype(int)
traintest["is_late_evening"] = (traintest.departer_hour >= 18).astype(int)
traintest.loc[
    (traintest.departer_hour >= 7) & (traintest.departer_hour < 18), "is_daytime"
] = 1
traintest["is_daytime"] = traintest["is_daytime"].fillna(0)
traintest["is_daytime"] = traintest["is_daytime"].astype(int)

# %%
traintest.is_daytime.value_counts()
# Out:
# 1    7696
# 0    5558
# Name: is_daytime, dtype: int64

# %%
def proc_text(s):
    dff = []
    for n, c in s.iteritems():
        #         c = CountVectorizer().fit_transform(c)
        c = TfidfVectorizer().fit_transform(c)
        dff.append(pd.DataFrame.sparse.from_spmatrix(c))
    return pd.concat(dff, axis=1)


tranformer = ColumnTransformer(
    transformers=[
        ("numeric", MinMaxScaler(), ["total_duration", "Total_Stops", "departer_hour"]),
        (
            "categorical",
            OneHotEncoder(),
            [
                "air",
                "Source",
                "Destination",
                "weekday",
                "month",
                "transit1",
                "transit2",
                "transit3",
            ],
        ),
        (
            "passthrough",
            FunctionTransformer(lambda x: x),
            [
                "is_daytime",
                "is_early_morning",
                "is_late_evening",
                "is_arrival_daytime",
                "is_arrival_early_morning",
                "is_arrival_late_evening",
                "meal_not_included",
                "baggage_not_included",
                "is_business",
                "is_premium_economy",
            ],
        ),
        #         ("text", FunctionTransformer(proc_text), ["Route"]),
    ],
)

traintestp = tranformer.fit_transform(traintest)
traintestp = scipy.sparse.csr_matrix(traintestp)

# %%
traintestp
# Out:
# <13254x121 sparse matrix of type '<class 'numpy.float64'>'
# 	with 170758 stored elements in Compressed Sparse Row format>

# %%
def metric(y_pred, y_true):
    y_pred = math.e ** y_pred
    y_true = math.e ** y_true
    return 1 - np.sqrt(np.square(np.log10(y_pred + 1) - np.log10(y_true + 1)).mean())

# %%
# model = MLPRegressor(hidden_layer_sizes=(40, 20))
model = LinearRegression()
cross_validate(
    model,
    traintestp[: len(train)],
    np.log(train.Price),
    cv=5,
    n_jobs=-1,
    scoring=make_scorer(metric, greater_is_better=True),
)
# Out:
# {'fit_time': array([0.11922812, 0.12093687, 0.12065172, 0.11926913, 0.10240293]),
#  'score_time': array([0.00124002, 0.00183606, 0.00149512, 0.00132895, 0.00141907]),
#  'test_score': array([0.90568705, 0.9088168 , 0.90495986, 0.90281671, 0.90829947])}

# %%
# model = LinearRegression()
# model.fit(traintestp[: len(train)], np.log(train.Price))
# price = model.predict(traintestp[len(train) :])
# price = math.e ** price
# test["Price"] = price
# test.to_excel("submission.xlsx")

# %%
model = LGBMRegressor()
cross_validate(
    model,
    traintestp[: len(train)],
    np.log(train.Price),
    cv=5,
    n_jobs=-1,
    scoring=make_scorer(metric, greater_is_better=True),
)
# Out:
# {'fit_time': array([0.10030198, 0.10460377, 0.10525393, 0.09699607, 0.09682274]),
#  'score_time': array([0.02232409, 0.02192736, 0.02342796, 0.02052116, 0.01997828]),
#  'test_score': array([0.9317947 , 0.93270821, 0.93099675, 0.92689504, 0.93363853])}

# %%
model = RandomForestRegressor()
cross_validate(
    model,
    traintestp[: len(train)],
    np.log(train.Price),
    cv=5,
    n_jobs=-1,
    scoring=make_scorer(metric, greater_is_better=True),
)
